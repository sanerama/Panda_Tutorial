# %%
import pandas as pd
import numpy as np
f = pd.read_csv('pandas_tutorial_read.csv', delimiter=';')
f
# Out:
#       2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9     2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10    2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia
# ...

# %%
s = f.iloc[0:10, 1:7]
s
# Out:
#    read  country_7  2458151261      SEO  North America
# 0  read  country_7  2458151262      SEO  South America
# 1  read  country_7  2458151263  AdWords         Africa
# 2  read  country_7  2458151264  AdWords         Europe
# 3  read  country_8  2458151265   Reddit  North America
# 4  read  country_6  2458151266   Reddit  North America
# 5  read  country_2  2458151267   Reddit         Europe
# 6  read  country_6  2458151268  AdWords         Europe
# 7  read  country_7  2458151269  AdWords  North America
# 8  read  country_5  2458151270   Reddit  North America
# 9  read  country_5  2458151271  AdWords           Asia

# %%
s.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
s.columns
# Out:
# Index(['read', 'country_7', '2458151261', 'SEO', 'North America'], dtype='object')

# %%
s.values
# Out:
# array([['read', 'country_7', 2458151262, 'SEO', 'South America'],
#        ['read', 'country_7', 2458151263, 'AdWords', 'Africa'],
#        ['read', 'country_7', 2458151264, 'AdWords', 'Europe'],
#        ['read', 'country_8', 2458151265, 'Reddit', 'North America'],
#        ['read', 'country_6', 2458151266, 'Reddit', 'North America'],
#        ['read', 'country_2', 2458151267, 'Reddit', 'Europe'],
#        ['read', 'country_6', 2458151268, 'AdWords', 'Europe'],
#        ['read', 'country_7', 2458151269, 'AdWords', 'North America'],
#        ['read', 'country_5', 2458151270, 'Reddit', 'North America'],
#        ['read', 'country_5', 2458151271, 'AdWords', 'Asia']], dtype=object)

# %%
#Transposing data
s.T
# Out:
#                            0           1           2              3  \
# read                    read        read        read           read
# country_7          country_7   country_7   country_7      country_8
# 2458151261        2458151262  2458151263  2458151264     2458151265
# SEO                      SEO     AdWords     AdWords         Reddit
# North America  South America      Africa      Europe  North America
#
#                            4           5           6              7  \
# read                    read        read        read           read
# country_7          country_6   country_2   country_6      country_7
# 2458151261        2458151266  2458151267  2458151268     2458151269
# SEO                   Reddit      Reddit     AdWords        AdWords
# North America  North America      Europe      Europe  North America
#
#                            8           9
# read                    read        read
# country_7          country_5   country_5
# ...

# %%
#sorting values by axis
s.sort_index(axis = 1,ascending = False)
# Out:
#    read  country_7      SEO  North America  2458151261
# 0  read  country_7      SEO  South America  2458151262
# 1  read  country_7  AdWords         Africa  2458151263
# 2  read  country_7  AdWords         Europe  2458151264
# 3  read  country_8   Reddit  North America  2458151265
# 4  read  country_6   Reddit  North America  2458151266
# 5  read  country_2   Reddit         Europe  2458151267
# 6  read  country_6  AdWords         Europe  2458151268
# 7  read  country_7  AdWords  North America  2458151269
# 8  read  country_5   Reddit  North America  2458151270
# 9  read  country_5  AdWords           Asia  2458151271

# %%
s.sort_values(by = 'SEO')
# Out:
#    read  country_7  2458151261      SEO  North America
# 1  read  country_7  2458151263  AdWords         Africa
# 2  read  country_7  2458151264  AdWords         Europe
# 6  read  country_6  2458151268  AdWords         Europe
# 7  read  country_7  2458151269  AdWords  North America
# 9  read  country_5  2458151271  AdWords           Asia
# 3  read  country_8  2458151265   Reddit  North America
# 4  read  country_6  2458151266   Reddit  North America
# 5  read  country_2  2458151267   Reddit         Europe
# 8  read  country_5  2458151270   Reddit  North America
# 0  read  country_7  2458151262      SEO  South America
