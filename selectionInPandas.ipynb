# %%
import pandas as pd
import numpy as np
f = pd.read_csv('pandas_tutorial_read.csv', delimiter=';')
f
# Out:
#       2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9     2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10    2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia
# ...

# %%
f['North America']
# Out:
# 0       South America
# 1              Africa
# 2              Europe
# 3       North America
# 4       North America
# 5              Europe
# 6              Europe
# 7       North America
# 8       North America
# 9                Asia
# 10          Australia
# 11               Asia
# 12             Europe
# 13             Africa
# 14      North America
# 15      North America
# 16               Asia
# 17      North America
# 18               Asia
# 19               Asia
# 20             Africa
# 21             Europe
# 22               Asia
# 23             Africa
# 24      North America
# 25      North America
# 26      North America
# 27               Asia
# 28               Asia
# 29      North America
#             ...
# 1764           Africa
# 1765             Asia
# 1766           Europe
# 1767    South America
# 1768        Australia
# 1769             Asia
# 1770           Africa
# 1771    South America
# 1772             Asia
# 1773             Asia
# ...

# %%
f[0:10]     #slicing first 10 rows
# Out:
#     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0   2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1   2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2   2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3   2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4   2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5   2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6   2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7   2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8   2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9   2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10  2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia

# %%
# selection by lable
f.loc[:,['read','SEO']]
# Out:
#       read      SEO
# 0     read      SEO
# 1     read  AdWords
# 2     read  AdWords
# 3     read   Reddit
# 4     read   Reddit
# 5     read   Reddit
# 6     read  AdWords
# 7     read  AdWords
# 8     read   Reddit
# 9     read  AdWords
# 10    read      SEO
# 11    read   Reddit
# 12    read   Reddit
# 13    read   Reddit
# 14    read      SEO
# 15    read      SEO
# 16    read   Reddit
# 17    read      SEO
# 18    read   Reddit
# 19    read   Reddit
# 20    read   Reddit
# 21    read  AdWords
# 22    read   Reddit
# 23    read   Reddit
# 24    read  AdWords
# 25    read      SEO
# 26    read      SEO
# 27    read   Reddit
# 28    read   Reddit
# 29    read      SEO
# ...    ...      ...
# 1764  read   Reddit
# 1765  read  AdWords
# 1766  read  AdWords
# 1767  read   Reddit
# 1768  read  AdWords
# 1769  read   Reddit
# 1770  read  AdWords
# 1771  read      SEO
# 1772  read   Reddit
# 1773  read  AdWords
# 1774  read  AdWords
# 1775  read   Reddit
# 1776  read      SEO
# ...

# %%
f.loc[1:10,['2458151261','North America']]
# Out:
#     2458151261  North America
# 1   2458151263         Africa
# 2   2458151264         Europe
# 3   2458151265  North America
# 4   2458151266  North America
# 5   2458151267         Europe
# 6   2458151268         Europe
# 7   2458151269  North America
# 8   2458151270  North America
# 9   2458151271           Asia
# 10  2458151272      Australia

# %%
#Selection by position
f.iloc[5]
# Out:
# 2018-01-01 00:01:01    2018-01-01 00:06:06
# read                                  read
# country_7                        country_2
# 2458151261                      2458151267
# SEO                                 Reddit
# North America                       Europe
# Name: 5, dtype: object

# %%
f.iloc[0:8,0:7]
# Out:
#    2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4  2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5  2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6  2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7  2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America

# %%
f.iloc[[1,4,5],[0,2]]
# Out:
#    2018-01-01 00:01:01  country_7
# 1  2018-01-01 00:04:01  country_7
# 4  2018-01-01 00:05:42  country_6
# 5  2018-01-01 00:06:06  country_2

# %%
#slicing rows explicitly
f.iloc[1:5,:]
# Out:
#    2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4  2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America

# %%
#getting value explicitely
f.iloc[2,3]
